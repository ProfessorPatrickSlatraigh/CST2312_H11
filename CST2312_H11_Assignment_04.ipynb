# %% [markdown]
# <a href="https://colab.research.google.com/github/ProfessorPatrickSlatraigh/CST2312_H11/blob/main/CST2312_H11_Assignment_04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **CST2312 Assignment 04**
#
# *by Professor Patrick, created 27-Sep-2021 | updated: 04-Feb-2023, 25-Feb-2025, 19-Sep-2025, 26-Jan-2026*
#
# This notebook includes scaffolding for an assignment on the use of regular expressions (REGEX) to wrangle data.

# %% [markdown]
# ## Homework Assignment 04

# %% [markdown]
# Imagine we want to conceal all phone numbers in a document.
# Read the below multiline docstring and substitute all phone numbers with
#
# 'XXX-XXX-XXXX'

# %%
docstring_text = """512-234-5234
foo
bar
124-512-5555
biz
125-555-5785
679-397-5255
2126660921
212-998-0902
888-888-2222
801-555-1211
802 555 1212
803.555.1213
(804) 555-1214
1-805-555-1215
1(806)555-1216
807-555-1217-1234
808-555-1218x1234
809-555-1219 ext. 1234
work 1-(810) 555.1220 #1234
"""

# %% [markdown]
# ### Your Solution for Assignment 04

# %%
## your solution here

# %% [markdown]
# ---
