# %% [markdown]
# <a href="https://colab.research.google.com/github/ProfessorPatrickSlatraigh/CST2312_H11/blob/main/WhatAboutPrint.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x = "Hello World!"

# %%
print(x)

# %% [markdown]
# **Be very careful using the `print = x` code in the next cell.**
# *Think about what it will really do and whether you want that to happen in your environment or not!*

# %%
print = x

# %%
print

# %%
print("Hello World!")

# %%
x("Hello World!")

# %%
dir(print)
